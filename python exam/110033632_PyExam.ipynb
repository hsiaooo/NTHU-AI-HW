# %% [markdown]
# # **Introduction to AI - Python Exam**
# * Only Python implementation will be accepted.
# * **Never Ever PLAGIARIZE.** (We will check program similarity.)
# * Save and create a copy of this notebook, coding in your own notebook.
#
# # Submission
#
# * Due day: **2021.09.23 12:00 noon**
# * Source code
#   * **StudentID_PyExam.ipynb**: contains all the results and codes for this exam.
#   * **StudentID_PyExam.py**: the content of this file must be consistent with .ipynb file.
#   * **output.csv**: the specify data assigned in last question.
# * You have to submit the three files. Only the above three files will be accepted, so the code of two exercises should be written in **one** .py file.

# %% [markdown]
# # 1. List and Tuple
#
# Read data row by row from the phone book **`people.csv`**, and store the records as a list of tuple. Each tuple holds a record of a person. Please read the following description before you start.
#
# Download **`people.csv`** via [this link](https://drive.google.com/file/d/1hoQCAIAWJh4e0MVsvXpqu0oVu84rKlSa/view?usp=sharing).
#
# The data are organized as follows:
# 1. Each record is seperated by a line break.
# 1. Each field is seperated by a comma.
#
# What are the fields?
# 1. Name
# 1. Birthday (YYYY/mm/dd)
# 1. Country
#
# ###**Your Tasks**
# **T1.** You are asked to write a program to read the **`people.csv`** file and convert the data into a list of tuple, in which the people are ordered by  their ages  (ascending).
# Your program **must** read the file **row by row**. Once you get a row,
# 1. replace the person's birthday with her/his age,
# 1. convert the person's data into a tuple,
# 1. find proper location in the list and **insert the tuple** so that the list of people **remains sorted by age**. You may simply compute the age by `(current year - the year that a person was born)` (no need to consider month and date).
#
# For example, a tuple should look like<br />
# `("Jakeem Garza", 29, "Canada,Embourg")`<br />
#
# If you print the list every time you read a new row, the changes should look like<br />
# ```
# # Reading the 1st line
# [
#   ("Cullen Hopkins", 46, "United States"),
# ]
# ```
#
# ```
# # Reading the 2nd line
# [
#   ("Stuart Joseph", 13, "France"),
#   ("Cullen Hopkins", 46, "United States"),
# ]
# ```
#
# ```
# # Reading the 3nd line
# [
#   ("Stuart Joseph", 13, "France"),
#   ("Cullen Hopkins", 46, "United States"),
#   ("Herrod Reilly", 100, "United States"),
# ]
# ```
#
# ```
# # Reading the 4th line
# [
#   ("Stuart Joseph", 13, "France"),
#   ("Cullen Hopkins", 46, "United States"),
#   ("Elijah Clay", 52, "United Kingdom"),
#   ("Herrod Reilly", 100, "United States")
# ]
# ```
# You can see that the people in the list are sort by their ages.
# <br /><br />
# **T2.** Find and remove from the list those people whose country is "United States" or "Cananda". After done, print the list.
# <br /><br />
# **T3.** Sort the remaining people by their last name (surname) and print the sorted list.

# %% [markdown]
# ###**Hint**
# How to read over the file and get one line at once?

# %%
f = open("people.csv", "r")

for line in f:
  line = line[:-1]   # This will remove the ending '\n' from the line.
  print(line)
  

f.close()
# Out:
# Name,Birthday,Country
# Cullen Hopkins,1975/07/31,United States
# Stuart Joseph,2008/12/16,France
# Herrod Reilly,1921/09/10,United States
# Elijah Clay,1969/05/12,United Kingdom
# Elvis Williamson,1951/04/15,Indonesia
# Evan Mcmillan,1953/03/28,Guinea-Bissau
# Alexander Gallegos,2016/02/12,Niue
# Quentin Bridges,1980/04/20,Tonga
# Stone Dillon,1982/12/12,Switzerland
# Finn Perkins,1984/09/16,Slovenia
# Matthew Lyons,1962/04/17,Tajikistan
# David Wallace,2003/02/20,Afghanistan
# Chaim Clemons,1967/02/08,Nigeria
# George Gutierrez,1925/02/01,Canada
# Ronan Carlson,1918/11/11,Nauru
# Myles Joyner,2006/02/02,Uruguay
# Barrett Stevenson,2005/01/19,Macedonia
# Amir Kaufman,1934/08/29,Liberia

# %% [markdown]
# **Answer of T1**

# %%
def del_1(li):
  li.remove(li[0])

def age(li, li_):
  temp = []
  for i in range(len(li)): # conver str to int
    y = int(li[i])
    temp.append(y)

  for j in range(len(temp)): 
    years_old = abs(temp[j] - 2021) # calculate ages
    li_.append(years_old)

def takeSecond(element): # get the second element
  return element[1]

def print_all(li):
  for i in range(len(li)):
    print(li[i])

def Stack(li):
  stack = []
  for i in range(len(li)):
    stack.append(li[i])
    print(stack)

# %%
Name = []
Year = []
Age = []
Country = []

f = open("people.csv", "r")

# Replace the person's birthday with her/his age
for line in f:
  line = line[:-1] # remove '\n'
  s_name = line.split(',', 1) # split from ,
  Name.append(s_name[0]) # add the first part of s_name, and this will be Name
  s_bir = s_name[1].split(',', 1) # split the second part of s_name from , and this will be Birthday and Country
  s_year = s_bir[0].split('/', 1) # split to the year
  Year.append(s_year[0]) 
  Country.append(s_bir[1])

del_1(Name); del_1(Year); del_1(Country) # delete the first str

age(Year, Age) # call the age function

# Convert the person's data into a tuple
persons = list(zip(Name, Age, Country)) # convert to list of tuple

# Sort by age
persons.sort(key=takeSecond) # sort the second element

print_all(persons) # If print raw by raw, it can't print out because it to long. So I print all by one times. 
# Stack(persons) # This function can print raw by raw.
# Out:
# ('Charles Mosley', 1, 'Australia')
# ('Burke Keller', 1, 'Macao')
# ('Blake Pacheco', 1, 'Canada')
# ('Theodore Hall', 1, 'Canada')
# ('Zane Barnes', 1, '"Palestine, State of"')
# ('Kenyon Hale', 2, 'Kazakhstan')
# ('Nathan Carter', 2, 'Switzerland')
# ('Theodore Miles', 2, 'Somalia')
# ('Gil Mendoza', 2, 'Australia')
# ('Devin Whitley', 2, 'Canada')
# ('Benjamin Leach', 2, 'Swaziland')
# ('Armand Johnson', 3, 'Tajikistan')
# ('Quinn James', 3, 'Gambia')
# ('Brady Phelps', 3, 'Brazil')
# ('Samson Melendez', 3, 'Canada')
# ('Kyle Nieves', 3, 'Nepal')
# ('Walter Velez', 4, 'Anguilla')
# ('Damian Perez', 4, 'Guernsey')
# ('Ryder Haley', 4, 'Liberia')
# ('Curran Calderon', 4, 'United Kingdom')
# ('Alexander Gallegos', 5, 'Niue')
# ('Logan Phillips', 5, 'Australia')
# ('Driscoll Finch', 5, 'France')
# ('Hasad Byrd', 5, 'Sint Maarten')
# ('Kevin Mann', 5, 'Lesotho')
# ('Neville Hart', 6, 'Iraq')
# ('Cooper Schroeder', 6, 'Tanzania')
# ('Beck Mayer', 6, 'Mayotte')
# ('Sylvester Hahn', 6, 'Madagascar')
# ('Kennan Wilkerson', 6, 'Canada')
# ('Burke Crawford', 6, 'Morocco')
# ('Jeremy Olsen', 6, 'Romania')
# ('Brandon Mcdowell', 7, 'Australia')
# ('Brendan Eaton', 7, 'Nigeria')
# ('Byron Carpenter', 7, 'Mozambique')
# ('Xenos Rhodes', 7, 'Palau')
# ('Tobias Ruiz', 7, 'Brazil')
# ('Ross Cervantes', 7, 'Guam')
# ('Brenden Short', 7, 'Gibraltar')
# ('Kelly Underwood', 7, 'Jersey')
# ('Hu Fischer', 8, 'Fiji')
# ('Wyatt Bradshaw', 8, 'Australia')
# ('Channing Potts', 8, '"Korea, South"')
# ('Brennan Randolph', 8, 'United States Minor Outlying Islands')
# ('Solomon Forbes', 8, 'Tokelau')
# ('Yuli Molina', 8, 'Brazil')
# ('Harlan Curry', 9, 'Canada')
# ('Devin Rosa', 9, 'Canada')
# ('Tarik Fitzpatrick', 9, 'Macedonia')
# ('Adam Fernandez', 10, 'Namibia')
# ('Maxwell Nguyen', 10, 'Guadeloupe')
# ('Aaron Mcdaniel', 10, 'Canada')
# ('Addison Hart', 10, 'Senegal')
# ('Hayden Cross', 11, 'Georgia')
# ('Graiden Kidd', 12, 'Sao Tome and Principe')
# ('Kareem Mccray', 12, 'Togo')
# ('Todd Coleman', 12, 'Jamaica')
# ('Blake Larson', 12, 'Canada')
# ('Barclay Mays', 12, 'Timor-Leste')
# ('Stuart Joseph', 13, 'France')
# ('Chase James', 13, 'Nepal')
# ('Craig Cooley', 14, 'Mayotte')
# ('Clark Rodriguez', 14, 'Mexico')
# ('Asher Banks', 14, 'Canada')
# ('Wade Medina', 14, 'Canada')
# ('Anthony Guzman', 14, 'Iran')
# ('Adrian Gould', 15, 'Canada')
# ('Preston Snow', 15, 'Zambia')
# ('Ciaran Lynn', 15, 'Gibraltar')
# ('Devin Hudson', 15, 'Canada')
# ('Myles Joyner', 15, 'Uruguay')
# ('Orlando Mooney', 16, 'Faroe Islands')
# ('Octavius Tyler', 16, 'Nauru')
# ('Darius Sanders', 16, 'Switzerland')
# ('Kermit Adams', 16, 'Canada')
# ('Brendan Howe', 16, 'Georgia')
# ('Barrett Stevenson', 16, 'Macedonia')
# ('Brandon Spears', 17, 'New Caledonia')
# ('Preston Fulton', 17, 'Uzbekistan')
# ('Lamar Camacho', 17, 'Falkland Islands')
# ('David Clemons', 17, 'Guinea')
# ('Vaughan Foley', 17, 'Tonga')
# ('Ignatius Levy', 18, 'San Marino')
# ('Amir Vaughan', 18, 'Mauritius')
# ('Erasmus Santos', 18, 'Iraq')
# ('Walker Thompson', 18, 'Fiji')
# ('Neville Livingston', 18, 'Samoa')
# ('David Wallace', 18, 'Afghanistan')
# ('Hamilton Avery', 19, 'Russian Federation')
# ('Paul Wynn', 19, 'Canada')
# ('Eric Andrews', 20, 'Canada')
# ('Cade Jimenez', 20, 'Montenegro')
# ('Arthur Hays', 20, 'Brazil')
# ('Lucius Hicks', 20, 'Canada')
# ('Jasper Frost', 20, 'Tokelau')
# ('Phelan Reed', 20, 'Saint Vincent and The Grenadines')
# ('Burke Sanford', 20, 'Portugal')
# ('Shad Jefferson', 21, 'Brazil')
# ('Berk Mcclain', 21, 'Australia')
# ('Cruz Rollins', 21, 'Canada')
# ('Malcolm Ball', 21, 'Luxembourg')
# ('Hamish Lindsay', 22, 'Canada')
# ('Vladimir Pacheco', 22, 'Micronesia')
# ('Harper Levy', 22, '"Korea, South"')
# ('Nathan Fields', 22, 'Suriname')
# ('Channing Molina', 22, 'Brazil')
# ('Ross Wheeler', 22, 'United States')
# ('Jameson Jarvis', 23, 'Australia')
# ('Prescott Phillips', 23, 'Tuvalu')
# ('Nathaniel Joseph', 23, '"Palestine, State of"')
# ('Gil William', 23, 'Svalbard and Jan Mayen Islands')
# ('Kadeem Perez', 23, 'Philippines')
# ('Brent Burke', 23, 'Sri Lanka')
# ('Avram Lara', 24, 'Kyrgyzstan')
# ('Zachary Bridges', 24, 'Mauritania')
# ('Myles Lawrence', 24, 'Switzerland')
# ('Aristotle White', 24, 'Mali')
# ('Gil Bryan', 25, 'Zambia')
# ('Calvin Daugherty', 25, 'Brazil')
# ('Colin Battle', 26, 'United Kingdom')
# ('Benjamin Burns', 26, 'Mexico')
# ('Keith Casey', 26, 'Zimbabwe')
# ('Theodore Hood', 26, 'Thailand')
# ('Zeus Rivera', 26, 'Fiji')
# ('Nasim Moore', 27, 'Iceland')
# ('Tyrone Cantu', 27, 'Montenegro')
# ('Honorato Prince', 27, 'Brazil')
# ('Wylie Maddox', 27, 'Guam')
# ('Kasimir Dennis', 27, 'United States')
# ('Nash Mckinney', 27, 'Gambia')
# ('Coby Jones', 28, 'United Arab Emirates')
# ('Damian Caldwell', 28, 'United States')
# ('Ralph Haley', 28, 'Peru')
# ('Uriah Conrad', 28, 'Uruguay')
# ('Lawrence Bennett', 29, 'Canada')
# ('Hall Campbell', 29, 'Sint Maarten')
# ('Fletcher Montgomery', 29, 'Singapore')
# ('Vladimir Todd', 29, 'Western Sahara')
# ('Jakeem Garza', 29, 'Canada')
# ('Christopher Savage', 30, 'Poland')
# ('Lucian Nieves', 30, 'Hungary')
# ('Amery Ashley', 30, 'Honduras')
# ('Ray Johnston', 30, 'Togo')
# ('Nathan Stanley', 30, 'Macao')
# ('Caleb Olson', 30, 'Brazil')
# ('Devin Hoffman', 31, 'Greenland')
# ('Duncan Fulton', 31, 'Syria')
# ('Channing Miller', 31, 'Panama')
# ('Jordan Turner', 31, 'Nicaragua')
# ('Ulric Yates', 31, 'French Southern Territories')
# ('Benjamin Bartlett', 31, 'Montenegro')
# ('Brandon Mcfadden', 32, 'Brazil')
# ('Macaulay Zimmerman', 32, 'Isle of Man')
# ('Nathan Rojas', 32, 'South Africa')
# ('Palmer Skinner', 32, 'Thailand')
# ('Kasimir Charles', 33, 'Sierra Leone')
# ('Marsden Pollard', 33, 'Canada')
# ('Hamish Skinner', 33, 'Canada')
# ('Adrian Sosa', 33, 'Australia')
# ('Ferdinand Williamson', 33, 'Swaziland')
# ('Stephen Trujillo', 33, 'Brazil')
# ('Vernon Gallagher', 33, 'Switzerland')
# ('Michael Valdez', 34, 'Guinea-Bissau')
# ('Noble Faulkner', 34, 'Tajikistan')
# ('Aquila Decker', 34, 'Canada')
# ('Tad Berger', 34, 'Spain')
# ('Devin Schneider', 34, 'Sierra Leone')
# ('Gray Sellers', 35, 'Saint Kitts and Nevis')
# ('Scott Tucker', 35, 'Brazil')
# ('Brandon Hubbard', 35, 'South Georgia and The South Sandwich Islands')
# ('Owen Schultz', 35, 'Martinique')
# ('Tate Kline', 36, 'Liberia')
# ('Jermaine Greene', 36, 'Grenada')
# ('Ryder Swanson', 36, 'Svalbard and Jan Mayen Islands')
# ('Nigel Garrison', 37, 'Guernsey')
# ('Hedley Morse', 37, 'United States')
# ('Hector Townsend', 37, 'Liechtenstein')
# ('Finn Perkins', 37, 'Slovenia')
# ('Brady Carlson', 38, 'United Kingdom')
# ('Mohammad Bowman', 38, 'Zimbabwe')
# ('Leroy Mayer', 38, 'Iceland')
# ('Jameson Kelley', 38, 'Zimbabwe')
# ('Stone Dillon', 39, 'Switzerland')
# ('Wyatt Cain', 39, 'Canada')
# ('Cody Robbins', 39, 'Trinidad and Tobago')
# ('Zachery Drake', 39, 'Saint Barthélemy')
# ('Anthony Kelley', 39, 'Sweden')
# ('Kibo James', 39, 'United States Minor Outlying Islands')
# ('Vaughan Suarez', 39, 'Micronesia')
# ('Emmanuel Jarvis', 40, 'Brazil')
# ('Malcolm Young', 40, 'Canada')
# ('Calvin Schmidt', 40, 'Norway')
# ('Berk Jarvis', 40, 'Nepal')
# ('Axel Ford', 40, 'Canada')
# ('Cullen Durham', 40, 'Australia')
# ('Quentin Bridges', 41, 'Tonga')
# ('Abdul Kerr', 41, 'United States')
# ('Blake Battle', 41, 'Montenegro')
# ('Duncan Tanner', 41, 'Martinique')
# ('Camden Hunt', 41, 'Nigeria')
# ('Graiden Gould', 41, 'Niue')
# ('Calvin Roy', 42, 'Australia')
# ('Ralph Tran', 42, 'Iraq')
# ('Anthony Sargent', 42, 'Western Sahara')
# ('Basil Higgins', 42, 'Zimbabwe')
# ('Steel Rivas', 42, 'Brazil')
# ('Cameron Obrien', 42, 'Australia')
# ('Scott Jones', 42, 'Isle of Man')
# ('Jonas Simpson', 43, 'Malaysia')
# ('Jordan Gallegos', 43, 'Canada')
# ('Aidan Vinson', 44, 'Iraq')
# ('Harrison Young', 44, 'Brazil')
# ('Russell Ballard', 44, 'Canada')
# ('Beau Harmon', 45, 'Serbia')
# ('Chandler Pratt', 45, 'Tonga')
# ('Walker Nichols', 45, 'United States Minor Outlying Islands')
# ('Cullen Hopkins', 46, 'United States')
# ('Axel Boyle', 46, 'United States Minor Outlying Islands')
# ('Nero Banks', 46, 'Australia')
# ('Macon Kramer', 46, 'Heard Island and Mcdonald Islands')
# ('Clark Hewitt', 46, 'Timor-Leste')
# ('Gil Justice', 46, 'Luxembourg')
# ('Hilel Middleton', 46, 'Australia')
# ('Timothy Hickman', 47, 'Australia')
# ('Allistair Mckay', 47, 'Holy See (Vatican City State)')
# ('Jerry Mclean', 47, 'New Caledonia')
# ('Upton Cobb', 47, 'Kenya')
# ('Cooper Brock', 47, 'Monaco')
# ('Kyle Hendricks', 48, 'Svalbard and Jan Mayen Islands')
# ('Carl Riley', 48, 'Guatemala')
# ('Kamal Robles', 48, 'Mexico')
# ('Ian Ashley', 48, 'Greenland')
# ('Bradley Mcbride', 48, 'Kenya')
# ('Hoyt Simmons', 48, 'South Sudan')
# ('Alexander Mullen', 49, 'Australia')
# ('Denton Burton', 49, 'Saint Vincent and The Grenadines')
# ('Xenos Vincent', 50, 'Kenya')
# ('Dane Patton', 50, 'Canada')
# ('Ishmael Wong', 50, 'Canada')
# ('Nolan Rojas', 50, 'Guernsey')
# ('Alfonso Ballard', 50, 'Greenland')
# ('Amery Nicholson', 51, 'Canada')
# ('Elvis Ramirez', 51, 'Australia')
# ('Mannix Gibson', 51, 'Uruguay')
# ('Elijah Clay', 52, 'United Kingdom')
# ('Travis Johnson', 52, 'Italy')
# ('Victor Quinn', 52, 'Timor-Leste')
# ('Jackson Frank', 52, 'Faroe Islands')
# ('Gabriel Curry', 52, 'Turkey')
# ('Scott Morse', 52, 'Slovenia')
# ('Giacomo Mitchell', 52, 'Ukraine')
# ('Macaulay Pearson', 52, '"Palestine, State of"')
# ('Jack Higgins', 53, 'Kiribati')
# ('Allistair Hart', 53, 'Canada')
# ('Alvin Hatfield', 54, 'Nicaragua')
# ('Driscoll Alford', 54, 'Australia')
# ('Troy Cleveland', 54, 'United States')
# ('Lucian Santiago', 54, 'San Marino')
# ('Ian Cameron', 54, 'Mozambique')
# ('Austin Hammond', 54, 'Peru')
# ('Joel Pitts', 54, 'Finland')
# ('Chaim Clemons', 54, 'Nigeria')
# ('Kareem Schroeder', 55, 'Australia')
# ('Philip Mckee', 56, 'Fiji')
# ('Porter Macias', 56, 'Saint Lucia')
# ('Philip Moses', 56, 'Canada')
# ('Berk Mosley', 56, 'Brazil')
# ('Hall Hensley', 56, 'Tanzania')
# ('Raja Pratt', 56, 'Venezuela')
# ('Malik Workman', 57, 'Slovakia')
# ('Carson Sanford', 57, 'Holy See (Vatican City State)')
# ('Armando Sampson', 57, 'United States')
# ('Victor Wilkinson', 57, 'Marshall Islands')
# ('Boris Ratliff', 57, 'Guinea')
# ('Steven Hodges', 57, 'French Polynesia')
# ('Callum May', 57, 'Papua New Guinea')
# ('Russell Love', 57, 'Canada')
# ('Grant Martin', 58, 'Australia')
# ('Dale Mcfadden', 58, 'Samoa')
# ('Buckminster Vang', 58, 'Netherlands')
# ('Deacon Mcgowan', 58, 'Sweden')
# ('Jesse Moran', 58, 'Suriname')
# ('Davis Meyer', 59, 'Uzbekistan')
# ('Rogan Gross', 59, 'Brazil')
# ('Hilel Wright', 59, 'India')
# ('Gannon Chase', 59, 'Gibraltar')
# ('Hector Clayton', 59, '"Korea, North"')
# ('Victor Zamora', 59, 'Marshall Islands')
# ('Matthew Lyons', 59, 'Tajikistan')
# ('Graiden Young', 60, 'Brazil')
# ('Patrick Curtis', 60, 'Qatar')
# ('Lamar Hall', 60, 'Saint Martin')
# ('Aquila Mosley', 61, 'Heard Island and Mcdonald Islands')
# ('Robert Cantrell', 61, 'Kenya')
# ('Edan Burke', 61, 'Canada')
# ('Keith Brennan', 61, 'Nauru')
# ('Lucas Morrison', 61, 'Canada')
# ('Burke Mcgee', 61, 'Singapore')
# ('Bruce Dotson', 61, 'Brazil')
# ('Hayes Warren', 61, 'Pakistan')
# ('Jason Branch', 61, 'Pitcairn Islands')
# ('Lawrence Charles', 62, 'Hong Kong')
# ('Murphy Gates', 62, 'Philippines')
# ('Erich Mcclure', 62, 'Brazil')
# ('Edan Alford', 62, 'Ghana')
# ('Steven Rowe', 62, 'Australia')
# ('Trevor Olson', 62, 'Spain')
# ('Leo Avila', 62, 'San Marino')
# ('Elvis Martinez', 62, 'Myanmar')
# ('Ferdinand Ewing', 63, 'Palau')
# ('Carl Walter', 63, 'Sudan')
# ('Lester Ford', 63, 'Canada')
# ('Hammett Eaton', 64, 'Philippines')
# ('Blake Dudley', 64, '"Korea, South"')
# ('Castor Tillman', 64, 'Tonga')
# ('Honorato Graves', 64, 'Guyana')
# ('Rajah Olson', 64, 'Sri Lanka')
# ('Carlos Rasmussen', 64, 'Thailand')
# ('Wesley Carter', 64, 'Lesotho')
# ('Matthew Banks', 65, 'Latvia')
# ('Arden Kemp', 65, 'New Zealand')
# ('Xavier Ramos', 65, 'Saint Pierre and Miquelon')
# ('Chase Ferguson', 66, 'Martinique')
# ('Nigel Golden', 66, 'Canada')
# ('Herman Pitts', 66, 'Guinea')
# ('Jonah Burch', 66, 'United States Minor Outlying Islands')
# ('Lyle Booker', 67, 'Paraguay')
# ('Beck Barr', 67, 'Pitcairn Islands')
# ('Zeus Chang', 67, 'Namibia')
# ('Jonas Pitts', 67, 'Heard Island and Mcdonald Islands')
# ('Peter Carpenter', 67, 'United Kingdom')
# ('Evan Mcmillan', 68, 'Guinea-Bissau')
# ('Dane Dominguez', 68, 'Gibraltar')
# ('Carter Craft', 68, 'Tajikistan')
# ('Reed King', 68, 'Canada')
# ('John Dudley', 68, 'Saint Pierre and Miquelon')
# ('Louis Ward', 68, 'Canada')
# ('Cody Neal', 69, 'Canada')
# ('Elvis Williamson', 70, 'Indonesia')
# ('Brady Schultz', 70, 'Saint Lucia')
# ('Travis Robinson', 70, 'Tokelau')
# ('Zeph Bruce', 70, 'Jamaica')
# ('Jacob Thomas', 70, 'Australia')
# ('Clarke Riggs', 70, 'Kenya')
# ('Nasim Sweet', 71, 'Thailand')
# ('Phelan Bray', 71, 'Reunion')
# ('Jordan Herman', 71, 'Finland')
# ('Drake Hanson', 71, 'Heard Island and Mcdonald Islands')
# ('Myles Mason', 72, 'Iceland')
# ('Warren Nieves', 72, 'Slovakia')
# ('Micah Stewart', 73, 'Monaco')
# ('Matthew Knowles', 73, 'Micronesia')
# ('Harper Diaz', 73, 'Canada')
# ('Ashton Emerson', 73, 'Zimbabwe')
# ('Ciaran Murray', 73, 'Australia')
# ('Ishmael Sharpe', 73, 'Pitcairn Islands')
# ('Dean Hodges', 73, 'Saint Kitts and Nevis')
# ('Brenden Clay', 74, 'Guinea-Bissau')
# ('Andrew Beard', 74, 'United Kingdom')
# ('Amos Hartman', 74, 'Jamaica')
# ('Emmanuel Bray', 74, 'Brazil')
# ('Coby Hammond', 75, 'Nigeria')
# ('Ferris Pugh', 75, 'Romania')
# ('Jasper Dennis', 75, 'United States Minor Outlying Islands')
# ('Buckminster Harvey', 75, 'New Caledonia')
# ('Hasad Gaines', 76, 'Brazil')
# ('Alan Haney', 76, 'Guernsey')
# ('Fletcher Howe', 78, 'India')
# ('Armand Paul', 78, 'Solomon Islands')
# ('Odysseus Campos', 78, 'Canada')
# ('Quinn Alexander', 78, 'Australia')
# ('August Munoz', 78, 'Nicaragua')
# ('Christian Odom', 78, 'Mauritius')
# ('Baker Joyce', 79, 'Morocco')
# ('Sylvester Murphy', 79, 'Mauritius')
# ('Cody Cline', 79, 'Brazil')
# ('Kenyon Burris', 79, 'Guatemala')
# ('Hashim Douglas', 79, 'Brazil')
# ('Quinlan Dunn', 80, 'Brazil')
# ('Daquan Bradford', 80, 'Singapore')
# ('Kadeem Patrick', 80, 'Canada')
# ('Caldwell Rogers', 81, 'Tajikistan')
# ('Marshall Roman', 81, '"Virgin Islands, United States"')
# ('Micah Cooley', 81, 'Malta')
# ('Nathaniel Lane', 81, 'Norfolk Island')
# ('John Riley', 82, 'Timor-Leste')
# ('Wang Merrill', 82, 'Canada')
# ('Armando Zimmerman', 82, 'Brazil')
# ('Oliver Carson', 82, 'Martinique')
# ('Akeem Rush', 82, 'South Georgia and The South Sandwich Islands')
# ('Allistair Allison', 82, 'Canada')
# ('Joshua Hampton', 83, 'Canada')
# ('Thaddeus Sawyer', 83, 'Nicaragua')
# ('Oscar Thomas', 84, 'Oman')
# ('Hu Armstrong', 84, 'Brazil')
# ('Ralph Hunter', 84, 'Honduras')
# ('Kuame Tate', 84, 'Brazil')
# ('Kaseem Orr', 84, 'Canada')
# ('Cadman Knapp', 84, 'Brazil')
# ('Hashim Knowles', 85, 'French Polynesia')
# ('Elliott Barry', 85, 'Brazil')
# ('Leo Madden', 85, 'Saint Kitts and Nevis')
# ('Zephania Duran', 85, 'Papua New Guinea')
# ('Ferris Rosa', 85, 'Germany')
# ('Robert Tran', 85, 'Afghanistan')
# ('Allen Barnett', 86, 'Sint Maarten')
# ('Tyrone Short', 86, 'Saint Barthélemy')
# ('Alvin Thompson', 86, 'Tokelau')
# ('Brian Kelley', 86, 'Guinea-Bissau')
# ('Ivor Dominguez', 86, 'Timor-Leste')
# ('Colorado Alford', 87, 'Canada')
# ('Ronan Mcleod', 87, 'Slovenia')
# ('Garrett Carney', 87, 'United States Minor Outlying Islands')
# ('Amir Kaufman', 87, 'Liberia')
# ('Brenden Hood', 88, 'Myanmar')
# ('Dolan Fleming', 88, 'Canada')
# ('Brody Ward', 88, 'Brazil')
# ('Brenden Hogan', 88, 'Yemen')
# ('Tarik Strong', 88, 'Norway')
# ('Jameson Rosa', 88, 'Mauritius')
# ('Hamilton Brown', 89, 'Niger')
# ('Andrew Mccarty', 89, 'Canada')
# ('Leroy Blackburn', 90, 'Oman')
# ('Hunter Bullock', 90, 'Switzerland')
# ('William Rowe', 90, 'Australia')
# ('Neville Sanford', 90, 'Malaysia')
# ('Zeph Cantu', 91, 'Macao')
# ('Scott West', 91, 'Monaco')
# ('Clarke Hoover', 91, 'Somalia')
# ('Erasmus Kramer', 91, 'Montserrat')
# ('Burke Cain', 91, 'Serbia')
# ('Hyatt Curtis', 91, 'Zambia')
# ('Xanthus Mcguire', 92, 'Turkmenistan')
# ('Cain Briggs', 92, 'Palau')
# ('Zachery Castillo', 93, 'Saint Barthélemy')
# ('Kareem Conner', 93, 'Hungary')
# ('Colin Lee', 94, 'French Guiana')
# ('Leonard Rodriguez', 94, 'Sao Tome and Principe')
# ('Randall Morton', 94, 'Netherlands')
# ('Erasmus Lawrence', 94, 'Guam')
# ('Chase Torres', 94, 'Brazil')
# ('Michael Dale', 95, 'United Kingdom')
# ('Berk Fox', 95, 'Australia')
# ('Ferdinand Ruiz', 95, 'Philippines')
# ('Flynn Robertson', 95, 'Ireland')
# ('Kaseem Ferrell', 95, 'Liechtenstein')
# ('Jonas Lawson', 95, 'Brazil')
# ('Omar Rosales', 96, 'Turks and Caicos Islands')
# ('Gavin Cervantes', 96, 'Laos')
# ('Wallace Phillips', 96, 'Brazil')
# ('Keaton Fowler', 96, 'Turks and Caicos Islands')
# ('Gage Dodson', 96, 'Canada')
# ('George Gutierrez', 96, 'Canada')
# ('Mohammad Cleveland', 97, 'United Kingdom')
# ('Nathan Gentry', 97, 'Australia')
# ('Oscar Wiggins', 97, 'San Marino')
# ('Elmo Koch', 98, 'Canada')
# ('Ashton Morrow', 98, 'Australia')
# ('Chester Parsons', 98, 'Libya')
# ('Yoshio Good', 98, 'French Southern Territories')
# ('Warren Parker', 98, 'Heard Island and Mcdonald Islands')
# ('Lucian Sargent', 98, 'Oman')
# ('Thor Park', 99, 'Australia')
# ('Julian Carpenter', 99, 'Australia')
# ('Wesley Mathews', 99, 'Kazakhstan')
# ('Herrod Reilly', 100, 'United States')
# ('Declan Ramirez', 100, 'Morocco')
# ('Gareth Foley', 100, '"Virgin Islands, United States"')
# ('Elijah Daniel', 100, 'Canada')
# ('Rajah Wall', 100, 'Montserrat')
# ('Jordan Lloyd', 101, 'Pitcairn Islands')
# ('Buckminster Mcclure', 101, 'Turkmenistan')
# ('Valentine Stevens', 101, 'Australia')
# ('Garrison Golden', 101, 'Netherlands')
# ('Bradley Campbell', 102, 'Canada')
# ('Fritz Hayes', 102, 'Malta')
# ('Owen Hancock', 102, 'Tunisia')
# ('Jerry Rivers', 102, 'Lithuania')
# ('Quamar Osborne', 102, 'Canada')
# ('Brody Reed', 102, 'Jamaica')
# ('Kato Jones', 102, 'Canada')
# ('Fulton Perez', 102, 'Singapore')
# ('Julian Harvey', 103, 'Italy')
# ('Timothy Morin', 103, 'Panama')
# ('Darius Marshall', 103, 'Myanmar')
# ('Harding Stevens', 103, 'Brazil')
# ('Garth Walters', 103, 'Australia')
# ('Tanner Hogan', 103, 'Jersey')
# ('Ronan Carlson', 103, 'Nauru')
# ('Owen Harrison', 104, 'Montenegro')
# ('Tiger Pierce', 104, '"Saint Helena, Ascension and Tristan da Cunha"')
# ('Tyler Wade', 104, 'Taiwan')
# ('Dale Powell', 104, 'Tunisia')
# ('Kyle Pratt', 104, 'Honduras')
# ('Steven Horn', 105, 'Timor-Leste')
# ('Vernon George', 105, 'Australia')
# ('Salvador Dale', 106, 'Namibia')
# ('Jelani Petersen', 106, 'Canada')
# ('Deacon Hammond', 106, 'Tuvalu')
# ('Ali Lowe', 106, 'Canada')

# %% [markdown]
# **Answer of T2**

# %%
del_i = []
person = persons.copy()

for i in range(len(persons)): 
  if person[i][2] == 'Canada' or person[i][2] == 'United States': # if person[i][2] is Canada or United States, i will be recorded.
    del_i.append(i)

for j in reversed(del_i): # if use original del_i, it will error, so need to use reversed(del_i)
  del person[j]

print_all(person)
# Out:
# ('Charles Mosley', 1, 'Australia')
# ('Burke Keller', 1, 'Macao')
# ('Zane Barnes', 1, '"Palestine, State of"')
# ('Kenyon Hale', 2, 'Kazakhstan')
# ('Nathan Carter', 2, 'Switzerland')
# ('Theodore Miles', 2, 'Somalia')
# ('Gil Mendoza', 2, 'Australia')
# ('Benjamin Leach', 2, 'Swaziland')
# ('Armand Johnson', 3, 'Tajikistan')
# ('Quinn James', 3, 'Gambia')
# ('Brady Phelps', 3, 'Brazil')
# ('Kyle Nieves', 3, 'Nepal')
# ('Walter Velez', 4, 'Anguilla')
# ('Damian Perez', 4, 'Guernsey')
# ('Ryder Haley', 4, 'Liberia')
# ('Curran Calderon', 4, 'United Kingdom')
# ('Alexander Gallegos', 5, 'Niue')
# ('Logan Phillips', 5, 'Australia')
# ('Driscoll Finch', 5, 'France')
# ('Hasad Byrd', 5, 'Sint Maarten')
# ('Kevin Mann', 5, 'Lesotho')
# ('Neville Hart', 6, 'Iraq')
# ('Cooper Schroeder', 6, 'Tanzania')
# ('Beck Mayer', 6, 'Mayotte')
# ('Sylvester Hahn', 6, 'Madagascar')
# ('Burke Crawford', 6, 'Morocco')
# ('Jeremy Olsen', 6, 'Romania')
# ('Brandon Mcdowell', 7, 'Australia')
# ('Brendan Eaton', 7, 'Nigeria')
# ('Byron Carpenter', 7, 'Mozambique')
# ('Xenos Rhodes', 7, 'Palau')
# ('Tobias Ruiz', 7, 'Brazil')
# ('Ross Cervantes', 7, 'Guam')
# ('Brenden Short', 7, 'Gibraltar')
# ('Kelly Underwood', 7, 'Jersey')
# ('Hu Fischer', 8, 'Fiji')
# ('Wyatt Bradshaw', 8, 'Australia')
# ('Channing Potts', 8, '"Korea, South"')
# ('Brennan Randolph', 8, 'United States Minor Outlying Islands')
# ('Solomon Forbes', 8, 'Tokelau')
# ('Yuli Molina', 8, 'Brazil')
# ('Tarik Fitzpatrick', 9, 'Macedonia')
# ('Adam Fernandez', 10, 'Namibia')
# ('Maxwell Nguyen', 10, 'Guadeloupe')
# ('Addison Hart', 10, 'Senegal')
# ('Hayden Cross', 11, 'Georgia')
# ('Graiden Kidd', 12, 'Sao Tome and Principe')
# ('Kareem Mccray', 12, 'Togo')
# ('Todd Coleman', 12, 'Jamaica')
# ('Barclay Mays', 12, 'Timor-Leste')
# ('Stuart Joseph', 13, 'France')
# ('Chase James', 13, 'Nepal')
# ('Craig Cooley', 14, 'Mayotte')
# ('Clark Rodriguez', 14, 'Mexico')
# ('Anthony Guzman', 14, 'Iran')
# ('Preston Snow', 15, 'Zambia')
# ('Ciaran Lynn', 15, 'Gibraltar')
# ('Myles Joyner', 15, 'Uruguay')
# ('Orlando Mooney', 16, 'Faroe Islands')
# ('Octavius Tyler', 16, 'Nauru')
# ('Darius Sanders', 16, 'Switzerland')
# ('Brendan Howe', 16, 'Georgia')
# ('Barrett Stevenson', 16, 'Macedonia')
# ('Brandon Spears', 17, 'New Caledonia')
# ('Preston Fulton', 17, 'Uzbekistan')
# ('Lamar Camacho', 17, 'Falkland Islands')
# ('David Clemons', 17, 'Guinea')
# ('Vaughan Foley', 17, 'Tonga')
# ('Ignatius Levy', 18, 'San Marino')
# ('Amir Vaughan', 18, 'Mauritius')
# ('Erasmus Santos', 18, 'Iraq')
# ('Walker Thompson', 18, 'Fiji')
# ('Neville Livingston', 18, 'Samoa')
# ('David Wallace', 18, 'Afghanistan')
# ('Hamilton Avery', 19, 'Russian Federation')
# ('Cade Jimenez', 20, 'Montenegro')
# ('Arthur Hays', 20, 'Brazil')
# ('Jasper Frost', 20, 'Tokelau')
# ('Phelan Reed', 20, 'Saint Vincent and The Grenadines')
# ('Burke Sanford', 20, 'Portugal')
# ('Shad Jefferson', 21, 'Brazil')
# ('Berk Mcclain', 21, 'Australia')
# ('Malcolm Ball', 21, 'Luxembourg')
# ('Vladimir Pacheco', 22, 'Micronesia')
# ('Harper Levy', 22, '"Korea, South"')
# ('Nathan Fields', 22, 'Suriname')
# ('Channing Molina', 22, 'Brazil')
# ('Jameson Jarvis', 23, 'Australia')
# ('Prescott Phillips', 23, 'Tuvalu')
# ('Nathaniel Joseph', 23, '"Palestine, State of"')
# ('Gil William', 23, 'Svalbard and Jan Mayen Islands')
# ('Kadeem Perez', 23, 'Philippines')
# ('Brent Burke', 23, 'Sri Lanka')
# ('Avram Lara', 24, 'Kyrgyzstan')
# ('Zachary Bridges', 24, 'Mauritania')
# ('Myles Lawrence', 24, 'Switzerland')
# ('Aristotle White', 24, 'Mali')
# ('Gil Bryan', 25, 'Zambia')
# ('Calvin Daugherty', 25, 'Brazil')
# ('Colin Battle', 26, 'United Kingdom')
# ('Benjamin Burns', 26, 'Mexico')
# ('Keith Casey', 26, 'Zimbabwe')
# ('Theodore Hood', 26, 'Thailand')
# ('Zeus Rivera', 26, 'Fiji')
# ('Nasim Moore', 27, 'Iceland')
# ('Tyrone Cantu', 27, 'Montenegro')
# ('Honorato Prince', 27, 'Brazil')
# ('Wylie Maddox', 27, 'Guam')
# ('Nash Mckinney', 27, 'Gambia')
# ('Coby Jones', 28, 'United Arab Emirates')
# ('Ralph Haley', 28, 'Peru')
# ('Uriah Conrad', 28, 'Uruguay')
# ('Hall Campbell', 29, 'Sint Maarten')
# ('Fletcher Montgomery', 29, 'Singapore')
# ('Vladimir Todd', 29, 'Western Sahara')
# ('Christopher Savage', 30, 'Poland')
# ('Lucian Nieves', 30, 'Hungary')
# ('Amery Ashley', 30, 'Honduras')
# ('Ray Johnston', 30, 'Togo')
# ('Nathan Stanley', 30, 'Macao')
# ('Caleb Olson', 30, 'Brazil')
# ('Devin Hoffman', 31, 'Greenland')
# ('Duncan Fulton', 31, 'Syria')
# ('Channing Miller', 31, 'Panama')
# ('Jordan Turner', 31, 'Nicaragua')
# ('Ulric Yates', 31, 'French Southern Territories')
# ('Benjamin Bartlett', 31, 'Montenegro')
# ('Brandon Mcfadden', 32, 'Brazil')
# ('Macaulay Zimmerman', 32, 'Isle of Man')
# ('Nathan Rojas', 32, 'South Africa')
# ('Palmer Skinner', 32, 'Thailand')
# ('Kasimir Charles', 33, 'Sierra Leone')
# ('Adrian Sosa', 33, 'Australia')
# ('Ferdinand Williamson', 33, 'Swaziland')
# ('Stephen Trujillo', 33, 'Brazil')
# ('Vernon Gallagher', 33, 'Switzerland')
# ('Michael Valdez', 34, 'Guinea-Bissau')
# ('Noble Faulkner', 34, 'Tajikistan')
# ('Tad Berger', 34, 'Spain')
# ('Devin Schneider', 34, 'Sierra Leone')
# ('Gray Sellers', 35, 'Saint Kitts and Nevis')
# ('Scott Tucker', 35, 'Brazil')
# ('Brandon Hubbard', 35, 'South Georgia and The South Sandwich Islands')
# ('Owen Schultz', 35, 'Martinique')
# ('Tate Kline', 36, 'Liberia')
# ('Jermaine Greene', 36, 'Grenada')
# ('Ryder Swanson', 36, 'Svalbard and Jan Mayen Islands')
# ('Nigel Garrison', 37, 'Guernsey')
# ('Hector Townsend', 37, 'Liechtenstein')
# ('Finn Perkins', 37, 'Slovenia')
# ('Brady Carlson', 38, 'United Kingdom')
# ('Mohammad Bowman', 38, 'Zimbabwe')
# ('Leroy Mayer', 38, 'Iceland')
# ('Jameson Kelley', 38, 'Zimbabwe')
# ('Stone Dillon', 39, 'Switzerland')
# ('Cody Robbins', 39, 'Trinidad and Tobago')
# ('Zachery Drake', 39, 'Saint Barthélemy')
# ('Anthony Kelley', 39, 'Sweden')
# ('Kibo James', 39, 'United States Minor Outlying Islands')
# ('Vaughan Suarez', 39, 'Micronesia')
# ('Emmanuel Jarvis', 40, 'Brazil')
# ('Calvin Schmidt', 40, 'Norway')
# ('Berk Jarvis', 40, 'Nepal')
# ('Cullen Durham', 40, 'Australia')
# ('Quentin Bridges', 41, 'Tonga')
# ('Blake Battle', 41, 'Montenegro')
# ('Duncan Tanner', 41, 'Martinique')
# ('Camden Hunt', 41, 'Nigeria')
# ('Graiden Gould', 41, 'Niue')
# ('Calvin Roy', 42, 'Australia')
# ('Ralph Tran', 42, 'Iraq')
# ('Anthony Sargent', 42, 'Western Sahara')
# ('Basil Higgins', 42, 'Zimbabwe')
# ('Steel Rivas', 42, 'Brazil')
# ('Cameron Obrien', 42, 'Australia')
# ('Scott Jones', 42, 'Isle of Man')
# ('Jonas Simpson', 43, 'Malaysia')
# ('Aidan Vinson', 44, 'Iraq')
# ('Harrison Young', 44, 'Brazil')
# ('Beau Harmon', 45, 'Serbia')
# ('Chandler Pratt', 45, 'Tonga')
# ('Walker Nichols', 45, 'United States Minor Outlying Islands')
# ('Axel Boyle', 46, 'United States Minor Outlying Islands')
# ('Nero Banks', 46, 'Australia')
# ('Macon Kramer', 46, 'Heard Island and Mcdonald Islands')
# ('Clark Hewitt', 46, 'Timor-Leste')
# ('Gil Justice', 46, 'Luxembourg')
# ('Hilel Middleton', 46, 'Australia')
# ('Timothy Hickman', 47, 'Australia')
# ('Allistair Mckay', 47, 'Holy See (Vatican City State)')
# ('Jerry Mclean', 47, 'New Caledonia')
# ('Upton Cobb', 47, 'Kenya')
# ('Cooper Brock', 47, 'Monaco')
# ('Kyle Hendricks', 48, 'Svalbard and Jan Mayen Islands')
# ('Carl Riley', 48, 'Guatemala')
# ('Kamal Robles', 48, 'Mexico')
# ('Ian Ashley', 48, 'Greenland')
# ('Bradley Mcbride', 48, 'Kenya')
# ('Hoyt Simmons', 48, 'South Sudan')
# ('Alexander Mullen', 49, 'Australia')
# ('Denton Burton', 49, 'Saint Vincent and The Grenadines')
# ('Xenos Vincent', 50, 'Kenya')
# ('Nolan Rojas', 50, 'Guernsey')
# ('Alfonso Ballard', 50, 'Greenland')
# ('Elvis Ramirez', 51, 'Australia')
# ('Mannix Gibson', 51, 'Uruguay')
# ('Elijah Clay', 52, 'United Kingdom')
# ('Travis Johnson', 52, 'Italy')
# ('Victor Quinn', 52, 'Timor-Leste')
# ('Jackson Frank', 52, 'Faroe Islands')
# ('Gabriel Curry', 52, 'Turkey')
# ('Scott Morse', 52, 'Slovenia')
# ('Giacomo Mitchell', 52, 'Ukraine')
# ('Macaulay Pearson', 52, '"Palestine, State of"')
# ('Jack Higgins', 53, 'Kiribati')
# ('Alvin Hatfield', 54, 'Nicaragua')
# ('Driscoll Alford', 54, 'Australia')
# ('Lucian Santiago', 54, 'San Marino')
# ('Ian Cameron', 54, 'Mozambique')
# ('Austin Hammond', 54, 'Peru')
# ('Joel Pitts', 54, 'Finland')
# ('Chaim Clemons', 54, 'Nigeria')
# ('Kareem Schroeder', 55, 'Australia')
# ('Philip Mckee', 56, 'Fiji')
# ('Porter Macias', 56, 'Saint Lucia')
# ('Berk Mosley', 56, 'Brazil')
# ('Hall Hensley', 56, 'Tanzania')
# ('Raja Pratt', 56, 'Venezuela')
# ('Malik Workman', 57, 'Slovakia')
# ('Carson Sanford', 57, 'Holy See (Vatican City State)')
# ('Victor Wilkinson', 57, 'Marshall Islands')
# ('Boris Ratliff', 57, 'Guinea')
# ('Steven Hodges', 57, 'French Polynesia')
# ('Callum May', 57, 'Papua New Guinea')
# ('Grant Martin', 58, 'Australia')
# ('Dale Mcfadden', 58, 'Samoa')
# ('Buckminster Vang', 58, 'Netherlands')
# ('Deacon Mcgowan', 58, 'Sweden')
# ('Jesse Moran', 58, 'Suriname')
# ('Davis Meyer', 59, 'Uzbekistan')
# ('Rogan Gross', 59, 'Brazil')
# ('Hilel Wright', 59, 'India')
# ('Gannon Chase', 59, 'Gibraltar')
# ('Hector Clayton', 59, '"Korea, North"')
# ('Victor Zamora', 59, 'Marshall Islands')
# ('Matthew Lyons', 59, 'Tajikistan')
# ('Graiden Young', 60, 'Brazil')
# ('Patrick Curtis', 60, 'Qatar')
# ('Lamar Hall', 60, 'Saint Martin')
# ('Aquila Mosley', 61, 'Heard Island and Mcdonald Islands')
# ('Robert Cantrell', 61, 'Kenya')
# ('Keith Brennan', 61, 'Nauru')
# ('Burke Mcgee', 61, 'Singapore')
# ('Bruce Dotson', 61, 'Brazil')
# ('Hayes Warren', 61, 'Pakistan')
# ('Jason Branch', 61, 'Pitcairn Islands')
# ('Lawrence Charles', 62, 'Hong Kong')
# ('Murphy Gates', 62, 'Philippines')
# ('Erich Mcclure', 62, 'Brazil')
# ('Edan Alford', 62, 'Ghana')
# ('Steven Rowe', 62, 'Australia')
# ('Trevor Olson', 62, 'Spain')
# ('Leo Avila', 62, 'San Marino')
# ('Elvis Martinez', 62, 'Myanmar')
# ('Ferdinand Ewing', 63, 'Palau')
# ('Carl Walter', 63, 'Sudan')
# ('Hammett Eaton', 64, 'Philippines')
# ('Blake Dudley', 64, '"Korea, South"')
# ('Castor Tillman', 64, 'Tonga')
# ('Honorato Graves', 64, 'Guyana')
# ('Rajah Olson', 64, 'Sri Lanka')
# ('Carlos Rasmussen', 64, 'Thailand')
# ('Wesley Carter', 64, 'Lesotho')
# ('Matthew Banks', 65, 'Latvia')
# ('Arden Kemp', 65, 'New Zealand')
# ('Xavier Ramos', 65, 'Saint Pierre and Miquelon')
# ('Chase Ferguson', 66, 'Martinique')
# ('Herman Pitts', 66, 'Guinea')
# ('Jonah Burch', 66, 'United States Minor Outlying Islands')
# ('Lyle Booker', 67, 'Paraguay')
# ('Beck Barr', 67, 'Pitcairn Islands')
# ('Zeus Chang', 67, 'Namibia')
# ('Jonas Pitts', 67, 'Heard Island and Mcdonald Islands')
# ('Peter Carpenter', 67, 'United Kingdom')
# ('Evan Mcmillan', 68, 'Guinea-Bissau')
# ('Dane Dominguez', 68, 'Gibraltar')
# ('Carter Craft', 68, 'Tajikistan')
# ('John Dudley', 68, 'Saint Pierre and Miquelon')
# ('Elvis Williamson', 70, 'Indonesia')
# ('Brady Schultz', 70, 'Saint Lucia')
# ('Travis Robinson', 70, 'Tokelau')
# ('Zeph Bruce', 70, 'Jamaica')
# ('Jacob Thomas', 70, 'Australia')
# ('Clarke Riggs', 70, 'Kenya')
# ('Nasim Sweet', 71, 'Thailand')
# ('Phelan Bray', 71, 'Reunion')
# ('Jordan Herman', 71, 'Finland')
# ('Drake Hanson', 71, 'Heard Island and Mcdonald Islands')
# ('Myles Mason', 72, 'Iceland')
# ('Warren Nieves', 72, 'Slovakia')
# ('Micah Stewart', 73, 'Monaco')
# ('Matthew Knowles', 73, 'Micronesia')
# ('Ashton Emerson', 73, 'Zimbabwe')
# ('Ciaran Murray', 73, 'Australia')
# ('Ishmael Sharpe', 73, 'Pitcairn Islands')
# ('Dean Hodges', 73, 'Saint Kitts and Nevis')
# ('Brenden Clay', 74, 'Guinea-Bissau')
# ('Andrew Beard', 74, 'United Kingdom')
# ('Amos Hartman', 74, 'Jamaica')
# ('Emmanuel Bray', 74, 'Brazil')
# ('Coby Hammond', 75, 'Nigeria')
# ('Ferris Pugh', 75, 'Romania')
# ('Jasper Dennis', 75, 'United States Minor Outlying Islands')
# ('Buckminster Harvey', 75, 'New Caledonia')
# ('Hasad Gaines', 76, 'Brazil')
# ('Alan Haney', 76, 'Guernsey')
# ('Fletcher Howe', 78, 'India')
# ('Armand Paul', 78, 'Solomon Islands')
# ('Quinn Alexander', 78, 'Australia')
# ('August Munoz', 78, 'Nicaragua')
# ('Christian Odom', 78, 'Mauritius')
# ('Baker Joyce', 79, 'Morocco')
# ('Sylvester Murphy', 79, 'Mauritius')
# ('Cody Cline', 79, 'Brazil')
# ('Kenyon Burris', 79, 'Guatemala')
# ('Hashim Douglas', 79, 'Brazil')
# ('Quinlan Dunn', 80, 'Brazil')
# ('Daquan Bradford', 80, 'Singapore')
# ('Caldwell Rogers', 81, 'Tajikistan')
# ('Marshall Roman', 81, '"Virgin Islands, United States"')
# ('Micah Cooley', 81, 'Malta')
# ('Nathaniel Lane', 81, 'Norfolk Island')
# ('John Riley', 82, 'Timor-Leste')
# ('Armando Zimmerman', 82, 'Brazil')
# ('Oliver Carson', 82, 'Martinique')
# ('Akeem Rush', 82, 'South Georgia and The South Sandwich Islands')
# ('Thaddeus Sawyer', 83, 'Nicaragua')
# ('Oscar Thomas', 84, 'Oman')
# ('Hu Armstrong', 84, 'Brazil')
# ('Ralph Hunter', 84, 'Honduras')
# ('Kuame Tate', 84, 'Brazil')
# ('Cadman Knapp', 84, 'Brazil')
# ('Hashim Knowles', 85, 'French Polynesia')
# ('Elliott Barry', 85, 'Brazil')
# ('Leo Madden', 85, 'Saint Kitts and Nevis')
# ('Zephania Duran', 85, 'Papua New Guinea')
# ('Ferris Rosa', 85, 'Germany')
# ('Robert Tran', 85, 'Afghanistan')
# ('Allen Barnett', 86, 'Sint Maarten')
# ('Tyrone Short', 86, 'Saint Barthélemy')
# ('Alvin Thompson', 86, 'Tokelau')
# ('Brian Kelley', 86, 'Guinea-Bissau')
# ('Ivor Dominguez', 86, 'Timor-Leste')
# ('Ronan Mcleod', 87, 'Slovenia')
# ('Garrett Carney', 87, 'United States Minor Outlying Islands')
# ('Amir Kaufman', 87, 'Liberia')
# ('Brenden Hood', 88, 'Myanmar')
# ('Brody Ward', 88, 'Brazil')
# ('Brenden Hogan', 88, 'Yemen')
# ('Tarik Strong', 88, 'Norway')
# ('Jameson Rosa', 88, 'Mauritius')
# ('Hamilton Brown', 89, 'Niger')
# ('Leroy Blackburn', 90, 'Oman')
# ('Hunter Bullock', 90, 'Switzerland')
# ('William Rowe', 90, 'Australia')
# ('Neville Sanford', 90, 'Malaysia')
# ('Zeph Cantu', 91, 'Macao')
# ('Scott West', 91, 'Monaco')
# ('Clarke Hoover', 91, 'Somalia')
# ('Erasmus Kramer', 91, 'Montserrat')
# ('Burke Cain', 91, 'Serbia')
# ('Hyatt Curtis', 91, 'Zambia')
# ('Xanthus Mcguire', 92, 'Turkmenistan')
# ('Cain Briggs', 92, 'Palau')
# ('Zachery Castillo', 93, 'Saint Barthélemy')
# ('Kareem Conner', 93, 'Hungary')
# ('Colin Lee', 94, 'French Guiana')
# ('Leonard Rodriguez', 94, 'Sao Tome and Principe')
# ('Randall Morton', 94, 'Netherlands')
# ('Erasmus Lawrence', 94, 'Guam')
# ('Chase Torres', 94, 'Brazil')
# ('Michael Dale', 95, 'United Kingdom')
# ('Berk Fox', 95, 'Australia')
# ('Ferdinand Ruiz', 95, 'Philippines')
# ('Flynn Robertson', 95, 'Ireland')
# ('Kaseem Ferrell', 95, 'Liechtenstein')
# ('Jonas Lawson', 95, 'Brazil')
# ('Omar Rosales', 96, 'Turks and Caicos Islands')
# ('Gavin Cervantes', 96, 'Laos')
# ('Wallace Phillips', 96, 'Brazil')
# ('Keaton Fowler', 96, 'Turks and Caicos Islands')
# ('Mohammad Cleveland', 97, 'United Kingdom')
# ('Nathan Gentry', 97, 'Australia')
# ('Oscar Wiggins', 97, 'San Marino')
# ('Ashton Morrow', 98, 'Australia')
# ('Chester Parsons', 98, 'Libya')
# ('Yoshio Good', 98, 'French Southern Territories')
# ('Warren Parker', 98, 'Heard Island and Mcdonald Islands')
# ('Lucian Sargent', 98, 'Oman')
# ('Thor Park', 99, 'Australia')
# ('Julian Carpenter', 99, 'Australia')
# ('Wesley Mathews', 99, 'Kazakhstan')
# ('Declan Ramirez', 100, 'Morocco')
# ('Gareth Foley', 100, '"Virgin Islands, United States"')
# ('Rajah Wall', 100, 'Montserrat')
# ('Jordan Lloyd', 101, 'Pitcairn Islands')
# ('Buckminster Mcclure', 101, 'Turkmenistan')
# ('Valentine Stevens', 101, 'Australia')
# ('Garrison Golden', 101, 'Netherlands')
# ('Fritz Hayes', 102, 'Malta')
# ('Owen Hancock', 102, 'Tunisia')
# ('Jerry Rivers', 102, 'Lithuania')
# ('Brody Reed', 102, 'Jamaica')
# ('Fulton Perez', 102, 'Singapore')
# ('Julian Harvey', 103, 'Italy')
# ('Timothy Morin', 103, 'Panama')
# ('Darius Marshall', 103, 'Myanmar')
# ('Harding Stevens', 103, 'Brazil')
# ('Garth Walters', 103, 'Australia')
# ('Tanner Hogan', 103, 'Jersey')
# ('Ronan Carlson', 103, 'Nauru')
# ('Owen Harrison', 104, 'Montenegro')
# ('Tiger Pierce', 104, '"Saint Helena, Ascension and Tristan da Cunha"')
# ('Tyler Wade', 104, 'Taiwan')
# ('Dale Powell', 104, 'Tunisia')
# ('Kyle Pratt', 104, 'Honduras')
# ('Steven Horn', 105, 'Timor-Leste')
# ('Vernon George', 105, 'Australia')
# ('Salvador Dale', 106, 'Namibia')
# ('Deacon Hammond', 106, 'Tuvalu')

# %% [markdown]
# **Answer of T3**

# %%
person_ = person.copy()

person_.sort(key=lambda person_: person_[:][0].split()[-1]) # split the first name to sort.
print_all(person_)
# Out:
# ('Quinn Alexander', 78, 'Australia')
# ('Driscoll Alford', 54, 'Australia')
# ('Edan Alford', 62, 'Ghana')
# ('Hu Armstrong', 84, 'Brazil')
# ('Amery Ashley', 30, 'Honduras')
# ('Ian Ashley', 48, 'Greenland')
# ('Hamilton Avery', 19, 'Russian Federation')
# ('Leo Avila', 62, 'San Marino')
# ('Malcolm Ball', 21, 'Luxembourg')
# ('Alfonso Ballard', 50, 'Greenland')
# ('Nero Banks', 46, 'Australia')
# ('Matthew Banks', 65, 'Latvia')
# ('Zane Barnes', 1, '"Palestine, State of"')
# ('Allen Barnett', 86, 'Sint Maarten')
# ('Beck Barr', 67, 'Pitcairn Islands')
# ('Elliott Barry', 85, 'Brazil')
# ('Benjamin Bartlett', 31, 'Montenegro')
# ('Colin Battle', 26, 'United Kingdom')
# ('Blake Battle', 41, 'Montenegro')
# ('Andrew Beard', 74, 'United Kingdom')
# ('Tad Berger', 34, 'Spain')
# ('Leroy Blackburn', 90, 'Oman')
# ('Lyle Booker', 67, 'Paraguay')
# ('Mohammad Bowman', 38, 'Zimbabwe')
# ('Axel Boyle', 46, 'United States Minor Outlying Islands')
# ('Daquan Bradford', 80, 'Singapore')
# ('Wyatt Bradshaw', 8, 'Australia')
# ('Jason Branch', 61, 'Pitcairn Islands')
# ('Phelan Bray', 71, 'Reunion')
# ('Emmanuel Bray', 74, 'Brazil')
# ('Keith Brennan', 61, 'Nauru')
# ('Zachary Bridges', 24, 'Mauritania')
# ('Quentin Bridges', 41, 'Tonga')
# ('Cain Briggs', 92, 'Palau')
# ('Cooper Brock', 47, 'Monaco')
# ('Hamilton Brown', 89, 'Niger')
# ('Zeph Bruce', 70, 'Jamaica')
# ('Gil Bryan', 25, 'Zambia')
# ('Hunter Bullock', 90, 'Switzerland')
# ('Jonah Burch', 66, 'United States Minor Outlying Islands')
# ('Brent Burke', 23, 'Sri Lanka')
# ('Benjamin Burns', 26, 'Mexico')
# ('Kenyon Burris', 79, 'Guatemala')
# ('Denton Burton', 49, 'Saint Vincent and The Grenadines')
# ('Hasad Byrd', 5, 'Sint Maarten')
# ('Burke Cain', 91, 'Serbia')
# ('Curran Calderon', 4, 'United Kingdom')
# ('Lamar Camacho', 17, 'Falkland Islands')
# ('Ian Cameron', 54, 'Mozambique')
# ('Hall Campbell', 29, 'Sint Maarten')
# ('Robert Cantrell', 61, 'Kenya')
# ('Tyrone Cantu', 27, 'Montenegro')
# ('Zeph Cantu', 91, 'Macao')
# ('Brady Carlson', 38, 'United Kingdom')
# ('Ronan Carlson', 103, 'Nauru')
# ('Garrett Carney', 87, 'United States Minor Outlying Islands')
# ('Byron Carpenter', 7, 'Mozambique')
# ('Peter Carpenter', 67, 'United Kingdom')
# ('Julian Carpenter', 99, 'Australia')
# ('Oliver Carson', 82, 'Martinique')
# ('Nathan Carter', 2, 'Switzerland')
# ('Wesley Carter', 64, 'Lesotho')
# ('Keith Casey', 26, 'Zimbabwe')
# ('Zachery Castillo', 93, 'Saint Barthélemy')
# ('Ross Cervantes', 7, 'Guam')
# ('Gavin Cervantes', 96, 'Laos')
# ('Zeus Chang', 67, 'Namibia')
# ('Kasimir Charles', 33, 'Sierra Leone')
# ('Lawrence Charles', 62, 'Hong Kong')
# ('Gannon Chase', 59, 'Gibraltar')
# ('Elijah Clay', 52, 'United Kingdom')
# ('Brenden Clay', 74, 'Guinea-Bissau')
# ('Hector Clayton', 59, '"Korea, North"')
# ('David Clemons', 17, 'Guinea')
# ('Chaim Clemons', 54, 'Nigeria')
# ('Mohammad Cleveland', 97, 'United Kingdom')
# ('Cody Cline', 79, 'Brazil')
# ('Upton Cobb', 47, 'Kenya')
# ('Todd Coleman', 12, 'Jamaica')
# ('Kareem Conner', 93, 'Hungary')
# ('Uriah Conrad', 28, 'Uruguay')
# ('Craig Cooley', 14, 'Mayotte')
# ('Micah Cooley', 81, 'Malta')
# ('Carter Craft', 68, 'Tajikistan')
# ('Burke Crawford', 6, 'Morocco')
# ('Hayden Cross', 11, 'Georgia')
# ('Gabriel Curry', 52, 'Turkey')
# ('Patrick Curtis', 60, 'Qatar')
# ('Hyatt Curtis', 91, 'Zambia')
# ('Michael Dale', 95, 'United Kingdom')
# ('Salvador Dale', 106, 'Namibia')
# ('Calvin Daugherty', 25, 'Brazil')
# ('Jasper Dennis', 75, 'United States Minor Outlying Islands')
# ('Stone Dillon', 39, 'Switzerland')
# ('Dane Dominguez', 68, 'Gibraltar')
# ('Ivor Dominguez', 86, 'Timor-Leste')
# ('Bruce Dotson', 61, 'Brazil')
# ('Hashim Douglas', 79, 'Brazil')
# ('Zachery Drake', 39, 'Saint Barthélemy')
# ('Blake Dudley', 64, '"Korea, South"')
# ('John Dudley', 68, 'Saint Pierre and Miquelon')
# ('Quinlan Dunn', 80, 'Brazil')
# ('Zephania Duran', 85, 'Papua New Guinea')
# ('Cullen Durham', 40, 'Australia')
# ('Brendan Eaton', 7, 'Nigeria')
# ('Hammett Eaton', 64, 'Philippines')
# ('Ashton Emerson', 73, 'Zimbabwe')
# ('Ferdinand Ewing', 63, 'Palau')
# ('Noble Faulkner', 34, 'Tajikistan')
# ('Chase Ferguson', 66, 'Martinique')
# ('Adam Fernandez', 10, 'Namibia')
# ('Kaseem Ferrell', 95, 'Liechtenstein')
# ('Nathan Fields', 22, 'Suriname')
# ('Driscoll Finch', 5, 'France')
# ('Hu Fischer', 8, 'Fiji')
# ('Tarik Fitzpatrick', 9, 'Macedonia')
# ('Vaughan Foley', 17, 'Tonga')
# ('Gareth Foley', 100, '"Virgin Islands, United States"')
# ('Solomon Forbes', 8, 'Tokelau')
# ('Keaton Fowler', 96, 'Turks and Caicos Islands')
# ('Berk Fox', 95, 'Australia')
# ('Jackson Frank', 52, 'Faroe Islands')
# ('Jasper Frost', 20, 'Tokelau')
# ('Preston Fulton', 17, 'Uzbekistan')
# ('Duncan Fulton', 31, 'Syria')
# ('Hasad Gaines', 76, 'Brazil')
# ('Vernon Gallagher', 33, 'Switzerland')
# ('Alexander Gallegos', 5, 'Niue')
# ('Nigel Garrison', 37, 'Guernsey')
# ('Murphy Gates', 62, 'Philippines')
# ('Nathan Gentry', 97, 'Australia')
# ('Vernon George', 105, 'Australia')
# ('Mannix Gibson', 51, 'Uruguay')
# ('Garrison Golden', 101, 'Netherlands')
# ('Yoshio Good', 98, 'French Southern Territories')
# ('Graiden Gould', 41, 'Niue')
# ('Honorato Graves', 64, 'Guyana')
# ('Jermaine Greene', 36, 'Grenada')
# ('Rogan Gross', 59, 'Brazil')
# ('Anthony Guzman', 14, 'Iran')
# ('Sylvester Hahn', 6, 'Madagascar')
# ('Kenyon Hale', 2, 'Kazakhstan')
# ('Ryder Haley', 4, 'Liberia')
# ('Ralph Haley', 28, 'Peru')
# ('Lamar Hall', 60, 'Saint Martin')
# ('Austin Hammond', 54, 'Peru')
# ('Coby Hammond', 75, 'Nigeria')
# ('Deacon Hammond', 106, 'Tuvalu')
# ('Owen Hancock', 102, 'Tunisia')
# ('Alan Haney', 76, 'Guernsey')
# ('Drake Hanson', 71, 'Heard Island and Mcdonald Islands')
# ('Beau Harmon', 45, 'Serbia')
# ('Owen Harrison', 104, 'Montenegro')
# ('Neville Hart', 6, 'Iraq')
# ('Addison Hart', 10, 'Senegal')
# ('Amos Hartman', 74, 'Jamaica')
# ('Buckminster Harvey', 75, 'New Caledonia')
# ('Julian Harvey', 103, 'Italy')
# ('Alvin Hatfield', 54, 'Nicaragua')
# ('Fritz Hayes', 102, 'Malta')
# ('Arthur Hays', 20, 'Brazil')
# ('Kyle Hendricks', 48, 'Svalbard and Jan Mayen Islands')
# ('Hall Hensley', 56, 'Tanzania')
# ('Jordan Herman', 71, 'Finland')
# ('Clark Hewitt', 46, 'Timor-Leste')
# ('Timothy Hickman', 47, 'Australia')
# ('Basil Higgins', 42, 'Zimbabwe')
# ('Jack Higgins', 53, 'Kiribati')
# ('Steven Hodges', 57, 'French Polynesia')
# ('Dean Hodges', 73, 'Saint Kitts and Nevis')
# ('Devin Hoffman', 31, 'Greenland')
# ('Brenden Hogan', 88, 'Yemen')
# ('Tanner Hogan', 103, 'Jersey')
# ('Theodore Hood', 26, 'Thailand')
# ('Brenden Hood', 88, 'Myanmar')
# ('Clarke Hoover', 91, 'Somalia')
# ('Steven Horn', 105, 'Timor-Leste')
# ('Brendan Howe', 16, 'Georgia')
# ('Fletcher Howe', 78, 'India')
# ('Brandon Hubbard', 35, 'South Georgia and The South Sandwich Islands')
# ('Camden Hunt', 41, 'Nigeria')
# ('Ralph Hunter', 84, 'Honduras')
# ('Quinn James', 3, 'Gambia')
# ('Chase James', 13, 'Nepal')
# ('Kibo James', 39, 'United States Minor Outlying Islands')
# ('Jameson Jarvis', 23, 'Australia')
# ('Emmanuel Jarvis', 40, 'Brazil')
# ('Berk Jarvis', 40, 'Nepal')
# ('Shad Jefferson', 21, 'Brazil')
# ('Cade Jimenez', 20, 'Montenegro')
# ('Armand Johnson', 3, 'Tajikistan')
# ('Travis Johnson', 52, 'Italy')
# ('Ray Johnston', 30, 'Togo')
# ('Coby Jones', 28, 'United Arab Emirates')
# ('Scott Jones', 42, 'Isle of Man')
# ('Stuart Joseph', 13, 'France')
# ('Nathaniel Joseph', 23, '"Palestine, State of"')
# ('Baker Joyce', 79, 'Morocco')
# ('Myles Joyner', 15, 'Uruguay')
# ('Gil Justice', 46, 'Luxembourg')
# ('Amir Kaufman', 87, 'Liberia')
# ('Burke Keller', 1, 'Macao')
# ('Jameson Kelley', 38, 'Zimbabwe')
# ('Anthony Kelley', 39, 'Sweden')
# ('Brian Kelley', 86, 'Guinea-Bissau')
# ('Arden Kemp', 65, 'New Zealand')
# ('Graiden Kidd', 12, 'Sao Tome and Principe')
# ('Tate Kline', 36, 'Liberia')
# ('Cadman Knapp', 84, 'Brazil')
# ('Matthew Knowles', 73, 'Micronesia')
# ('Hashim Knowles', 85, 'French Polynesia')
# ('Macon Kramer', 46, 'Heard Island and Mcdonald Islands')
# ('Erasmus Kramer', 91, 'Montserrat')
# ('Nathaniel Lane', 81, 'Norfolk Island')
# ('Avram Lara', 24, 'Kyrgyzstan')
# ('Myles Lawrence', 24, 'Switzerland')
# ('Erasmus Lawrence', 94, 'Guam')
# ('Jonas Lawson', 95, 'Brazil')
# ('Benjamin Leach', 2, 'Swaziland')
# ('Colin Lee', 94, 'French Guiana')
# ('Ignatius Levy', 18, 'San Marino')
# ('Harper Levy', 22, '"Korea, South"')
# ('Neville Livingston', 18, 'Samoa')
# ('Jordan Lloyd', 101, 'Pitcairn Islands')
# ('Ciaran Lynn', 15, 'Gibraltar')
# ('Matthew Lyons', 59, 'Tajikistan')
# ('Porter Macias', 56, 'Saint Lucia')
# ('Leo Madden', 85, 'Saint Kitts and Nevis')
# ('Wylie Maddox', 27, 'Guam')
# ('Kevin Mann', 5, 'Lesotho')
# ('Darius Marshall', 103, 'Myanmar')
# ('Grant Martin', 58, 'Australia')
# ('Elvis Martinez', 62, 'Myanmar')
# ('Myles Mason', 72, 'Iceland')
# ('Wesley Mathews', 99, 'Kazakhstan')
# ('Callum May', 57, 'Papua New Guinea')
# ('Beck Mayer', 6, 'Mayotte')
# ('Leroy Mayer', 38, 'Iceland')
# ('Barclay Mays', 12, 'Timor-Leste')
# ('Bradley Mcbride', 48, 'Kenya')
# ('Berk Mcclain', 21, 'Australia')
# ('Erich Mcclure', 62, 'Brazil')
# ('Buckminster Mcclure', 101, 'Turkmenistan')
# ('Kareem Mccray', 12, 'Togo')
# ('Brandon Mcdowell', 7, 'Australia')
# ('Brandon Mcfadden', 32, 'Brazil')
# ('Dale Mcfadden', 58, 'Samoa')
# ('Burke Mcgee', 61, 'Singapore')
# ('Deacon Mcgowan', 58, 'Sweden')
# ('Xanthus Mcguire', 92, 'Turkmenistan')
# ('Allistair Mckay', 47, 'Holy See (Vatican City State)')
# ('Philip Mckee', 56, 'Fiji')
# ('Nash Mckinney', 27, 'Gambia')
# ('Jerry Mclean', 47, 'New Caledonia')
# ('Ronan Mcleod', 87, 'Slovenia')
# ('Evan Mcmillan', 68, 'Guinea-Bissau')
# ('Gil Mendoza', 2, 'Australia')
# ('Davis Meyer', 59, 'Uzbekistan')
# ('Hilel Middleton', 46, 'Australia')
# ('Theodore Miles', 2, 'Somalia')
# ('Channing Miller', 31, 'Panama')
# ('Giacomo Mitchell', 52, 'Ukraine')
# ('Yuli Molina', 8, 'Brazil')
# ('Channing Molina', 22, 'Brazil')
# ('Fletcher Montgomery', 29, 'Singapore')
# ('Orlando Mooney', 16, 'Faroe Islands')
# ('Nasim Moore', 27, 'Iceland')
# ('Jesse Moran', 58, 'Suriname')
# ('Timothy Morin', 103, 'Panama')
# ('Ashton Morrow', 98, 'Australia')
# ('Scott Morse', 52, 'Slovenia')
# ('Randall Morton', 94, 'Netherlands')
# ('Charles Mosley', 1, 'Australia')
# ('Berk Mosley', 56, 'Brazil')
# ('Aquila Mosley', 61, 'Heard Island and Mcdonald Islands')
# ('Alexander Mullen', 49, 'Australia')
# ('August Munoz', 78, 'Nicaragua')
# ('Sylvester Murphy', 79, 'Mauritius')
# ('Ciaran Murray', 73, 'Australia')
# ('Maxwell Nguyen', 10, 'Guadeloupe')
# ('Walker Nichols', 45, 'United States Minor Outlying Islands')
# ('Kyle Nieves', 3, 'Nepal')
# ('Lucian Nieves', 30, 'Hungary')
# ('Warren Nieves', 72, 'Slovakia')
# ('Cameron Obrien', 42, 'Australia')
# ('Christian Odom', 78, 'Mauritius')
# ('Jeremy Olsen', 6, 'Romania')
# ('Caleb Olson', 30, 'Brazil')
# ('Trevor Olson', 62, 'Spain')
# ('Rajah Olson', 64, 'Sri Lanka')
# ('Vladimir Pacheco', 22, 'Micronesia')
# ('Thor Park', 99, 'Australia')
# ('Warren Parker', 98, 'Heard Island and Mcdonald Islands')
# ('Chester Parsons', 98, 'Libya')
# ('Armand Paul', 78, 'Solomon Islands')
# ('Macaulay Pearson', 52, '"Palestine, State of"')
# ('Damian Perez', 4, 'Guernsey')
# ('Kadeem Perez', 23, 'Philippines')
# ('Fulton Perez', 102, 'Singapore')
# ('Finn Perkins', 37, 'Slovenia')
# ('Brady Phelps', 3, 'Brazil')
# ('Logan Phillips', 5, 'Australia')
# ('Prescott Phillips', 23, 'Tuvalu')
# ('Wallace Phillips', 96, 'Brazil')
# ('Tiger Pierce', 104, '"Saint Helena, Ascension and Tristan da Cunha"')
# ('Joel Pitts', 54, 'Finland')
# ('Herman Pitts', 66, 'Guinea')
# ('Jonas Pitts', 67, 'Heard Island and Mcdonald Islands')
# ('Channing Potts', 8, '"Korea, South"')
# ('Dale Powell', 104, 'Tunisia')
# ('Chandler Pratt', 45, 'Tonga')
# ('Raja Pratt', 56, 'Venezuela')
# ('Kyle Pratt', 104, 'Honduras')
# ('Honorato Prince', 27, 'Brazil')
# ('Ferris Pugh', 75, 'Romania')
# ('Victor Quinn', 52, 'Timor-Leste')
# ('Elvis Ramirez', 51, 'Australia')
# ('Declan Ramirez', 100, 'Morocco')
# ('Xavier Ramos', 65, 'Saint Pierre and Miquelon')
# ('Brennan Randolph', 8, 'United States Minor Outlying Islands')
# ('Carlos Rasmussen', 64, 'Thailand')
# ('Boris Ratliff', 57, 'Guinea')
# ('Phelan Reed', 20, 'Saint Vincent and The Grenadines')
# ('Brody Reed', 102, 'Jamaica')
# ('Xenos Rhodes', 7, 'Palau')
# ('Clarke Riggs', 70, 'Kenya')
# ('Carl Riley', 48, 'Guatemala')
# ('John Riley', 82, 'Timor-Leste')
# ('Steel Rivas', 42, 'Brazil')
# ('Zeus Rivera', 26, 'Fiji')
# ('Jerry Rivers', 102, 'Lithuania')
# ('Cody Robbins', 39, 'Trinidad and Tobago')
# ('Flynn Robertson', 95, 'Ireland')
# ('Travis Robinson', 70, 'Tokelau')
# ('Kamal Robles', 48, 'Mexico')
# ('Clark Rodriguez', 14, 'Mexico')
# ('Leonard Rodriguez', 94, 'Sao Tome and Principe')
# ('Caldwell Rogers', 81, 'Tajikistan')
# ('Nathan Rojas', 32, 'South Africa')
# ('Nolan Rojas', 50, 'Guernsey')
# ('Marshall Roman', 81, '"Virgin Islands, United States"')
# ('Ferris Rosa', 85, 'Germany')
# ('Jameson Rosa', 88, 'Mauritius')
# ('Omar Rosales', 96, 'Turks and Caicos Islands')
# ('Steven Rowe', 62, 'Australia')
# ('William Rowe', 90, 'Australia')
# ('Calvin Roy', 42, 'Australia')
# ('Tobias Ruiz', 7, 'Brazil')
# ('Ferdinand Ruiz', 95, 'Philippines')
# ('Akeem Rush', 82, 'South Georgia and The South Sandwich Islands')
# ('Darius Sanders', 16, 'Switzerland')
# ('Burke Sanford', 20, 'Portugal')
# ('Carson Sanford', 57, 'Holy See (Vatican City State)')
# ('Neville Sanford', 90, 'Malaysia')
# ('Lucian Santiago', 54, 'San Marino')
# ('Erasmus Santos', 18, 'Iraq')
# ('Anthony Sargent', 42, 'Western Sahara')
# ('Lucian Sargent', 98, 'Oman')
# ('Christopher Savage', 30, 'Poland')
# ('Thaddeus Sawyer', 83, 'Nicaragua')
# ('Calvin Schmidt', 40, 'Norway')
# ('Devin Schneider', 34, 'Sierra Leone')
# ('Cooper Schroeder', 6, 'Tanzania')
# ('Kareem Schroeder', 55, 'Australia')
# ('Owen Schultz', 35, 'Martinique')
# ('Brady Schultz', 70, 'Saint Lucia')
# ('Gray Sellers', 35, 'Saint Kitts and Nevis')
# ('Ishmael Sharpe', 73, 'Pitcairn Islands')
# ('Brenden Short', 7, 'Gibraltar')
# ('Tyrone Short', 86, 'Saint Barthélemy')
# ('Hoyt Simmons', 48, 'South Sudan')
# ('Jonas Simpson', 43, 'Malaysia')
# ('Palmer Skinner', 32, 'Thailand')
# ('Preston Snow', 15, 'Zambia')
# ('Adrian Sosa', 33, 'Australia')
# ('Brandon Spears', 17, 'New Caledonia')
# ('Nathan Stanley', 30, 'Macao')
# ('Valentine Stevens', 101, 'Australia')
# ('Harding Stevens', 103, 'Brazil')
# ('Barrett Stevenson', 16, 'Macedonia')
# ('Micah Stewart', 73, 'Monaco')
# ('Tarik Strong', 88, 'Norway')
# ('Vaughan Suarez', 39, 'Micronesia')
# ('Ryder Swanson', 36, 'Svalbard and Jan Mayen Islands')
# ('Nasim Sweet', 71, 'Thailand')
# ('Duncan Tanner', 41, 'Martinique')
# ('Kuame Tate', 84, 'Brazil')
# ('Jacob Thomas', 70, 'Australia')
# ('Oscar Thomas', 84, 'Oman')
# ('Walker Thompson', 18, 'Fiji')
# ('Alvin Thompson', 86, 'Tokelau')
# ('Castor Tillman', 64, 'Tonga')
# ('Vladimir Todd', 29, 'Western Sahara')
# ('Chase Torres', 94, 'Brazil')
# ('Hector Townsend', 37, 'Liechtenstein')
# ('Ralph Tran', 42, 'Iraq')
# ('Robert Tran', 85, 'Afghanistan')
# ('Stephen Trujillo', 33, 'Brazil')
# ('Scott Tucker', 35, 'Brazil')
# ('Jordan Turner', 31, 'Nicaragua')
# ('Octavius Tyler', 16, 'Nauru')
# ('Kelly Underwood', 7, 'Jersey')
# ('Michael Valdez', 34, 'Guinea-Bissau')
# ('Buckminster Vang', 58, 'Netherlands')
# ('Amir Vaughan', 18, 'Mauritius')
# ('Walter Velez', 4, 'Anguilla')
# ('Xenos Vincent', 50, 'Kenya')
# ('Aidan Vinson', 44, 'Iraq')
# ('Tyler Wade', 104, 'Taiwan')
# ('Rajah Wall', 100, 'Montserrat')
# ('David Wallace', 18, 'Afghanistan')
# ('Carl Walter', 63, 'Sudan')
# ('Garth Walters', 103, 'Australia')
# ('Brody Ward', 88, 'Brazil')
# ('Hayes Warren', 61, 'Pakistan')
# ('Scott West', 91, 'Monaco')
# ('Aristotle White', 24, 'Mali')
# ('Oscar Wiggins', 97, 'San Marino')
# ('Victor Wilkinson', 57, 'Marshall Islands')
# ('Gil William', 23, 'Svalbard and Jan Mayen Islands')
# ('Ferdinand Williamson', 33, 'Swaziland')
# ('Elvis Williamson', 70, 'Indonesia')
# ('Malik Workman', 57, 'Slovakia')
# ('Hilel Wright', 59, 'India')
# ('Ulric Yates', 31, 'French Southern Territories')
# ('Harrison Young', 44, 'Brazil')
# ('Graiden Young', 60, 'Brazil')
# ('Victor Zamora', 59, 'Marshall Islands')
# ('Macaulay Zimmerman', 32, 'Isle of Man')
# ('Armando Zimmerman', 82, 'Brazil')

# %% [markdown]
# # 2. Pandas DataFrame
# * Download `wine.csv` via this [link](https://drive.google.com/file/d/1bHVv8qfL-2Jjk8vnmMFVe0x0EYcyBNBq/view?usp=sharing).
# 1. Read `wine.csv` into dataframe, then check the info of data (Print out some features of the dataframe).
# 2. Perform data pre-processing (standardization):  Z = (X - mean)/std.  (Do it with the information you got from 1., don't use packages or module functions.)
# 3. Slice data and leave only row 3 ~ 9 (include row 9), column 2 ~ 11 (include col 11).
# 4. Output an csv file `output.csv` without index.

# %%
import pandas as pd

def ReadFile(filename):
  df = pd.read_csv('{}'.format(filename)) # read file
  return df

def standardization(df, cols):
  data = df.copy()
  for col in cols: 
      data_ = data[col].copy()

      Mean = data_.mean() # mean of each column
      Std = data_.std() # std of each column
      
      z_score = (data_ - Mean) / Std 
      data[col] = z_score

  return data

def export_csv(csv_name, df):
  df.to_csv(csv_name, index=False) # export csv

# %%
df = ReadFile('wine.csv')
print('Original df:\n', df)
print('------------------------------')
print('Describe of df:\n', df.describe())
print('------------------------------')
print(df.info())
print('------------------------------')
Standardization = pd.DataFrame(standardization(df, df.keys()))
print('After standardization:\n', Standardization)
print('------------------------------')
df_ = Standardization.iloc[3:10, 2:12]
print('Only raw 3 ~ 9, column 2 ~ 11:\n', df_)
export_csv('output.csv', df_)
# Out:
# Original df:
#       Alcohol  Malic acid   Ash  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0      14.23        1.71  2.43  ...  1.04                          3.92     1065
# 1      13.20        1.78  2.14  ...  1.05                          3.40     1050
# 2      13.16        2.36  2.67  ...  1.03                          3.17     1185
# 3      14.37        1.95  2.50  ...  0.86                          3.45     1480
# 4      13.24        2.59  2.87  ...  1.04                          2.93      735
# ..       ...         ...   ...  ...   ...                           ...      ...
# 173    13.71        5.65  2.45  ...  0.64                          1.74      740
# 174    13.40        3.91  2.48  ...  0.70                          1.56      750
# 175    13.27        4.28  2.26  ...  0.59                          1.56      835
# 176    13.17        2.59  2.37  ...  0.60                          1.62      840
# 177    14.13        4.10  2.74  ...  0.61                          1.60      560
#
# [178 rows x 13 columns]
# ------------------------------
# Describe of df:
#            Alcohol  Malic acid  ...  OD280/OD315 of diluted wines      Proline
# count  178.000000  178.000000  ...                    178.000000   178.000000
# mean    13.000618    2.336348  ...                      2.611685   746.893258
# std      0.811827    1.117146  ...                      0.709990   314.907474
# min     11.030000    0.740000  ...                      1.270000   278.000000
# 25%     12.362500    1.602500  ...                      1.937500   500.500000
# 50%     13.050000    1.865000  ...                      2.780000   673.500000
# 75%     13.677500    3.082500  ...                      3.170000   985.000000
# max     14.830000    5.800000  ...                      4.000000  1680.000000
#
# [8 rows x 13 columns]
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malic acid                    178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity of ash             178 non-null    float64
#  4   Magnesium                     178 non-null    int64
#  5   Total phenols                 178 non-null    float64
#  6   Flavanoids                    178 non-null    float64
#  7   Nonflavanoid phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  OD280/OD315 of diluted wines  178 non-null    float64
#  12  Proline                       178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB
# None
# ------------------------------
# After standardization:
#        Alcohol  Malic acid  ...  OD280/OD315 of diluted wines   Proline
# 0    1.514341   -0.560668  ...                      1.842721  1.010159
# 1    0.245597   -0.498009  ...                      1.110317  0.962526
# 2    0.196325    0.021172  ...                      0.786369  1.391224
# 3    1.686791   -0.345835  ...                      1.180741  2.328007
# 4    0.294868    0.227053  ...                      0.448336 -0.037767
# ..        ...         ...  ...                           ...       ...
# 173  0.873810    2.966176  ...                     -1.227742 -0.021890
# 174  0.491955    1.408636  ...                     -1.481267  0.009866
# 175  0.331822    1.739837  ...                     -1.481267  0.279786
# 176  0.208643    0.227053  ...                     -1.396759  0.295664
# 177  1.391162    1.578712  ...                     -1.424928 -0.593486
#
# [178 rows x 13 columns]
# ------------------------------
# Only raw 3 ~ 9, column 2 ~ 11:
#          Ash  Alcalinity of ash  ...       Hue  OD280/OD315 of diluted wines
# 3  0.486554          -0.806975  ... -0.426341                      1.180741
# 4  1.835226           0.450674  ...  0.361158                      0.448336
# 5  0.304301          -1.286079  ...  0.404908                      0.335659
# 6  0.304301          -1.465743  ...  0.273659                      1.363842
# 7  0.887510          -0.567423  ...  0.448658                      1.363842
# 8 -0.716315          -1.645408  ...  0.536158                      0.335659
# 9 -0.351810          -1.046527  ...  0.229909                      1.321588
#
# [7 rows x 10 columns]
